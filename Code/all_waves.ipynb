# %% [markdown]
# <h1>View all Wavelengths</h1>
#
# View all wavelengths of either an image or a difference image
#
# TODO: make easy way to use an existing .fits file without going through Fido

# %% [markdown]
# Import stuff

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
import sunpy.map
import sunpy.io.fits as fits
from sunpy.visualization import axis_labels_from_ctype
from sunpy.net import Fido, attrs as a
import astropy.units as u
from astropy.time import Time
import warnings

#select directory
# %cd .
# Out:
# C:\myStuff\school\PHYS 477\AIAfiles

# %% [markdown]
# Specify the images to use and grab through Fido

# %%
cadence = 2*u.minute #Time before event to difference
start = Time('2021-01-04T12:48') #Time of the event, to minute precision
end = start + 59*u.second #End of the Fido search range

#Times for the prior image to difference with
prestart = start-cadence
preend = end-cadence

# %% [markdown]
# Search for and grab the images (will take a bit to run)

# %%
wvs = [94, 131, 171, 193, 211, 304, 335, 1600, 1700]*u.angstrom #available wavelengths (AA)

downds = []
predownds = []

for wvl in wvs:
    result = Fido.search(a.Time(start,end), a.Instrument.aia, a.Wavelength(wvl), a.Sample(cadence))
    preresult = Fido.search(a.Time(prestart,preend), a.Instrument.aia, a.Wavelength(wvl), a.Sample(cadence))
    
    downds.append(Fido.fetch(result, path='./{file}', progress=True))
    predownds.append(Fido.fetch(preresult, path='./{file}', progress=True))
# Out:
# Files Downloaded: 100%|██████████| 1/1 [00:07<00:00,  7.29s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:06<00:00,  6.89s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:08<00:00,  8.77s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:10<00:00, 10.13s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:11<00:00, 11.17s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:09<00:00,  9.37s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:09<00:00,  9.08s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:10<00:00, 10.54s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:08<00:00,  8.25s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:08<00:00,  8.25s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:08<00:00,  8.67s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:10<00:00, 10.44s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:10<00:00, 10.86s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:09<00:00,  9.40s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:07<00:00,  7.20s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:08<00:00,  8.25s/file]
# Files Downloaded: 100%|██████████| 1/1 [00:08<00:00,  8.05s/file]
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   0%|          | 0.00/12.6M [00:00<?, ?B/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   0%|          | 100/12.6M [00:10<354:04:23, 9.88B/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   0%|          | 50.9k/12.6M [00:10<29:37, 7.06kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   1%|          | 130k/12.6M [00:10<09:22, 22.2kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   2%|▏         | 211k/12.6M [00:10<04:44, 43.5kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   3%|▎         | 334k/12.6M [00:10<02:20, 87.2kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   4%|▍         | 484k/12.6M [00:10<01:16, 158kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   5%|▌         | 679k/12.6M [00:10<00:43, 277kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   7%|▋         | 909k/12.6M [00:10<00:26, 449kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:   9%|▉         | 1.18M/12.6M [00:11<00:16, 672kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  11%|█         | 1.35M/12.6M [00:11<00:14, 767kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  12%|█▏        | 1.51M/12.6M [00:11<00:12, 884kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  13%|█▎        | 1.67M/12.6M [00:11<00:11, 970kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:
B/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  78%|███████▊  | 9.78M/12.6M [00:19<00:14, 196kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  78%|███████▊  | 9.84M/12.6M [00:19<00:13, 211kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  79%|███████▊  | 9.89M/12.6M [00:19<00:12, 222kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  79%|███████▉  | 9.94M/12.6M [00:19<00:10, 244kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  79%|███████▉  | 9.99M/12.6M [00:19<00:09, 262kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  80%|███████▉  | 10.1M/12.6M [00:19<00:08, 301kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  80%|████████  | 10.1M/12.6M [00:20<00:07, 349kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  81%|████████  | 10.2M/12.6M [00:20<00:05, 410kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  82%|████████▏ | 10.3M/12.6M [00:20<00:04, 483kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  82%|████████▏ | 10.4M/12.6M [00:20<00:03, 582kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  83%|████████▎ | 10.5M/12.6M [00:20<00:03, 602kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  84%|████████▎ | 10.5M/12.6M [00:21<00:07, 272kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  84%|████████▍ | 10.6M/12.6M [00:21<00:05, 353kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  85%|████████▌ | 10.7M/12.6M [00:21<00:04, 450kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  86%|████████▌ | 10.8M/12.6M [00:21<00:02, 587kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  87%|████████▋ | 11.0M/12.6M [00:21<00:02, 674kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  88%|████████▊ | 11.1M/12.6M [00:21<00:01, 819kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  89%|████████▉ | 11.2M/12.6M [00:21<00:01, 943kB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  90%|█████████ | 11.4M/12.6M [00:21<00:01, 1.07MB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  91%|█████████▏| 11.5M/12.6M [00:21<00:01, 1.09MB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  93%|█████████▎| 11.7M/12.6M [00:22<00:00, 1.25MB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  94%|█████████▎| 11.8M/12.6M [00:22<00:00, 1.23MB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  95%|█████████▍| 11.9M/12.6M [00:22<00:00, 1.20MB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  96%|█████████▌| 12.1M/12.6M [00:22<00:00, 1.24MB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  97%|█████████▋| 12.2M/12.6M [00:22<00:00, 1.29MB/s]
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits:  98%|█████████▊| 12.4M/12.6M [00:22<00:00, 1.30MB/s]
# Files Downloaded: 100%|██████████| 1/1 [00:33<00:00, 33.00s/file]█████▉| 12.5M/12.6M [00:22<00:00, 1.37MB/s]
#
# aia_lev1_1700a_2021_01_04t12_46_04_71z_image_lev1.fits: 100%|██████████| 12.6M/12.6M [00:37<00:00, 1.37MB/s]

# %% [markdown]
# Create Sunpy Maps from the downloaded files

# %%
smap = [sunpy.map.Map(file) for file in downds]
presmap = [sunpy.map.Map(file) for file in predownds]

n_wvs = len(smap)

# %% [markdown]
# Create difference images

# %%
diffs = [sunpy.map.Map(smap[i].data-presmap[i].data, smap[i].meta)
         for i in range(n_wvs)]

# %% [markdown]
# Plot it out

# %%
#Plot the 9 wavelengths in a 3-by-3 grid
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=(9,9))
ax = ax.reshape(-1)

#set this to smap if you want to view just the event image
toplot = diffs

#suppress recurrent warning
warnings.filterwarnings("ignore")

for i in range(n_wvs):
    toplot[i].plot(axes=ax[i], clip_interval=(1,100)*u.percent, annotate=False)
    toplot[i].draw_limb() #draws a circle on the limb of the Sun
    ax[i].set_title(toplot[i].wavelength)

    cb = plt.colorbar()
    tick_locator = ticker.MaxNLocator(nbins=5)
    cb.locator = tick_locator
    cb.update_ticks()

#share axis labels over the whole figure
ax[3].set_ylabel(axis_labels_from_ctype(toplot[3].coordinate_system[1],
                                        toplot[3].spatial_units[1]))
ax[7].set_xlabel(axis_labels_from_ctype(toplot[7].coordinate_system[0],
                                        toplot[7].spatial_units[0]))
# Out:
# Text(0.5, 0, 'Helioprojective Longitude (Solar-X) [arcsec]')

# %% [markdown]
# There's no actual flare happening during these images, this is just an example
